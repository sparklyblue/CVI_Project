# %% [markdown]
# # Exploratory Data Analysis of Images for Species Classification
# The information gathered in this notebook from the dataset can be found in ```results.md```

# %%
from species_classification import load_dataset, calc_flight_stats
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781537864.405649    6006 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X_train, y_train, flight_train = load_dataset("../images_filtered/train", "../labels_filtered/train")
X_val, y_val, flight_val = load_dataset("../images_filtered/val", "../labels_filtered/val")
X_test, y_test, flight_test = load_dataset("../images_filtered/test", "../labels_filtered/test")

# %%
print("Number of images per split")

print("Train: ", len(X_train))
print("Val: ", len(X_val))
print("Test: ", len(X_test))
# Out:
# Number of images per split
# Train:  31037
# Val:  5414
# Test:  4632

# %%
print("Number of images per species per split")

print("Train: ")
for spec, img in zip(np.unique_counts(y_train)[0], np.unique_counts(y_train)[1]):
    print(f"\tclass {spec}: {img} images -> {img/len(y_train):.3f} %")
print("Val: ")
for spec, img in zip(np.unique_counts(y_val)[0], np.unique_counts(y_val)[1]):
    print(f"\tclass {spec}: {img} images -> {img/len(y_val):.3f} %")

print("Test: ")
for spec, img in zip(np.unique_counts(y_test)[0], np.unique_counts(y_test)[1]):
    print(f"\tclass {spec}: {img} images -> {img/len(y_test):.3f} %")
# big problem: only 12 samples of class 2 (Fallow Deer)
# Out:
# Number of images per species per split
# Train:
# 	class 0: 2751 images -> 0.089 %
# 	class 1: 10048 images -> 0.324 %
# 	class 2: 4040 images -> 0.130 %
# 	class 3: 13496 images -> 0.435 %
# 	class 4: 702 images -> 0.023 %
# Val:
# 	class 0: 1732 images -> 0.320 %
# 	class 1: 2508 images -> 0.463 %
# 	class 2: 214 images -> 0.040 %
# 	class 3: 781 images -> 0.144 %
# 	class 4: 179 images -> 0.033 %
# Test:
# 	class 0: 961 images -> 0.207 %
# 	class 1: 1552 images -> 0.335 %
# 	class 2: 12 images -> 0.003 %
# 	class 3: 1943 images -> 0.419 %
# 	class 4: 164 images -> 0.035 %

# %%
print("Number of different flights per split")

print("Train: ", len(np.unique(flight_train)))
print("Val: ", len(np.unique(flight_val)))
print("Test: ", len(np.unique(flight_test)))
# Out:
# Number of different flights per split
# Train:  159
# Val:  24
# Test:  42

# %% [markdown]
# ## Comparing Images of the different datasets
#
# In this section I compared the images from the train, validation, and test dataset with each other. I had a closer look at their brightness, contrast, and range (max pixel value - min pixel value).

# %%
calc_flight_stats(flight_train, y_train, X_train)
# Out:
# train flight ids + statistic
# for flight 0 and species 3:
# min: 43.16834677419355, max: 83.50828853046595, mean: 58.41942213362821, median: 58.113911290322584
# min: 7.254659695211672, max: 23.93287957913204, mean: 16.325999192666103, median: 15.793275320574702
# min: 43, max: 249, mean: 165, median: 182
# for flight 1 and species 1:
# min: 26.50258064516129, max: 106.43087121212122, mean: 65.68621845326965, median: 65.88442940892861
# min: 3.3112926746021074, max: 62.14699557878104, mean: 31.670928417751757, median: 30.265387087841034
# min: 34, max: 255, mean: 198, median: 215.0
# for flight 2 and species 1:
# min: 23.40462962962963, max: 124.09227594339623, mean: 74.54812128626347, median: 75.56185483870968
# min: 4.201958926667975, max: 66.24990695495833, mean: 26.78923239112295, median: 26.48816182410679
# min: 28, max: 255, mean: 177, median: 192.0
# for flight 3 and species 1:
# min: 27.761708697889862, max: 132.6256868131868, mean: 89.82976834273914, median: 91.72653846153847
# min: 3.44473255757519, max: 69.38708036672605, mean: 27.222676224249323, median: 22.787283600252515
# min: 25, max: 255, mean: 167, median: 180.0
# for flight 17 and species 1:
# min: 12.441787941787942, max: 118.19992144540456, mean: 70.60438142101775, median: 69.66236143040229
# min: 24.89772719057879, max: 67.34712624229824, mean: 52.573683029379744, median: 53.08488462399713
# min: 186, max: 255, mean: 232, median: 234.5
# for flight 17 and species 2:
# min: 0.0, max: 185.1941638608305, mean: 88.3457213555387, median: 87.79444444444445
# min: 0.0, max: 99.29199090398157, mean: 54.60402183161452, median: 53.50680558522767
# min: 0, max: 255, mean: 222, median: 226.0
# for flight 18 and species 1:
# min: 54.95056497175141, max: 198.1121157323689, mean: 140.2813172217376, median: 144.53509154315606
# min: 12.744680526416898, max: 103.42033095784441, mean: 33.599437027468994, median: 30.344463762829523
# min: 94, max: 255, mean: 179, median: 177
# for flight 20 and species 1:
# min: 10.304183467741936, max: 163.22627314814815, mean: 99.2512225455874, median: 106.10391439031258
# min: 4.844735872264957, max: 80.10225363812724, mean: 28.832056992952133, median: 25.161656009131253
# min: 34, max: 246, mean: 141, median: 152
# for flight 21 and species 1:
# min: 31.65525925925926, max: 179.65885750962772, mean: 110.06688591680225, median: 109.13570974906926
# min: 7.380579719591554, max: 86.38872891337671, mean: 34.204307732648516, median: 28.507418731138575
# min: 54, max: 240, mean: 154, median: 154.0
# for flight 26 and species 3:
# min: 13.775976418570377, max: 201.40217391304347, mean: 91.71984689089943, median: 79.20517241379311
# min: 3.4730237251047775, max: 98.27047516873267, mean: 36.92267486295929, median: 32.809548845370855
# min: 40, max: 255, mean: 172, median: 167
# for flight 27 and species 3:
# min: 21.982222222222223, max: 204.44666666666666, mean: 99.44520529157211, median: 84.69566377171216
# min: 8.160187800585744, max: 98.18835609358149, mean: 38.314029443717025, median: 33.85233435342777
# min: 56, max: 255, mean: 197, median: 209.0
# for flight 28 and species 3:
# min: 25.990431930016403, max: 151.83913412563666, mean: 75.48231036700011, median: 69.65105601469237
# min: 10.033003385086358, max: 70.71212758304173, mean: 34.38442275719842, median: 37.14438247790429
# min: 34, max: 255, mean: 200, median: 210
# for flight 29 and species 3:
# min: 11.125752230753267, max: 165.8106960950764, mean: 64.20406046750473, median: 56.15768799102133
# min: 32.33713340541481, max: 88.17983110315397, mean: 49.66968601190468, median: 49.429549375254325
# min: 134, max: 255, mean: 244, median: 251
# for flight 30 and species 3:
# min: 17.64351851851852, max: 118.82579185520362, mean: 56.89880775162272, median: 58.21870286576169
# min: 24.978946759935866, max: 62.90391524796283, mean: 45.467015265257345, median: 46.25268164781177
# min: 189, max: 255, mean: 249, median: 255
# for flight 31 and species 3:
# min: 10.88905325443787, max: 129.4674107142857, mean: 64.13441475945109, median: 58.63108974358974
# min: 15.997630992870993, max: 78.64096264633618, mean: 39.61301760592945, median: 38.42473706829537
# min: 93, max: 255, mean: 234, median: 246.0
# for flight 32 and species 1:
# min: 11.871443907675792, max: 132.43648097826087, mean: 72.40923354885058, median: 69.29548872180452
# min: 12.17196347994961, max: 59.219864299783026, mean: 29.272382383787903, median: 24.078532447522395
# min: 123, max: 255, mean: 214, median: 220
# for flight 34 and species 3:
# min: 19.817434210526315, max: 139.01077586206895, mean: 63.03454289972834, median: 56.82258870564718
# min: 17.53991489102192, max: 64.19564786897772, mean: 46.17872776962925, median: 46.557073190956984
# min: 141, max: 255, mean: 244, median: 247
# for flight 35 and species 3:
# min: 22.235507246376812, max: 141.25094482237338, mean: 64.5723714709541, median: 58.9546485260771
# min: 20.61512070511707, max: 71.31126305016562, mean: 45.34455339923773, median: 46.28664156116958
# min: 144, max: 255, mean: 241, median: 251
# for flight 40 and species 3:
# min: 24.56038647342995, max: 152.89612590799032, mean: 101.80713461033643, median: 103.86731234866828
# min: 9.368728276662017, max: 62.91936212091457, mean: 39.358830194989594, median: 38.81030148212955
# min: 78, max: 255, mean: 229, median: 231
# for flight 41 and species 3:
# min: 15.764516129032257, max: 166.7275974025974, mean: 64.50004630283158, median: 61.826470588235296
# min: 15.692200222708204, max: 83.90192445385095, mean: 31.600759527497512, median: 27.547936929391717
# min: 134, max: 255, mean: 213, median: 231
# for flight 42 and species 3:
# min: 21.618861364624077, max: 130.88702539017004, mean: 66.84832857593966, median: 60.26777777777778
# min: 7.049617777047855, max: 82.81826493167142, mean: 40.10830808923016, median: 39.2339371458151
# min: 88, max: 255, mean: 219, median: 248
# for flight 44 and species 3:
# min: 8.098765432098766, max: 187.58069852941176, mean: 78.29732067951652, median: 74.91018591254254
# min: 19.210725488239223, max: 78.33557988559892, mean: 46.551441356510914, median: 45.86676251612638
# min: 109, max: 255, mean: 243, median: 255
# for flight 45 and species 3:
# min: 20.150913673597984, max: 169.27932576539388, mean: 101.31484056331203, median: 99.9746855345912
# min: 13.701802284289156, max: 92.73710256619088, mean: 52.92934137582189, median: 55.60613896899803
# min: 161, max: 255, mean: 239, median: 252.5
# for flight 46 and species 3:
# min: 0.0, max: 193.90885002649708, mean: 125.86788239016565, median: 129.1578947368421
# min: 0.0, max: 101.95642897551866, mean: 46.69840840246068, median: 45.957924031506245
# min: 0, max: 255, mean: 194, median: 194
# for flight 47 and species 3:
# min: 1.6598535172883666, max: 170.56006493506493, mean: 113.91942581345641, median: 120.30329012961117
# min: 7.803180525315298, max: 94.48500904370192, mean: 44.024334679586964, median: 41.56560945124291
# min: 69, max: 255, mean: 195, median: 198
# for flight 48 and species 0:
# min: 16.499573742540495, max: 174.8391620498615, mean: 94.4746189929172, median: 98.38493038493039
# min: 7.436857760890686, max: 93.8331790933635, mean: 46.43563995499271, median: 45.74138727349559
# min: 89, max: 255, mean: 223, median: 231
# for flight 52 and species 3:
# min: 7.706551535087719, max: 198.9022177419355, mean: 152.3293392896266, median: 165.65231988568783
# min: 11.449532309958428, max: 103.81286820502169, mean: 32.52454922541994, median: 24.193445837462555
# min: 101, max: 255, mean: 173, median: 162.0
# for flight 53 and species 3:
# min: 26.189593375355333, max: 200.76215738284705, mean: 146.80924947900016, median: 158.48810190369542
# min: 9.260609636356245, max: 99.80347604721767, mean: 41.36967999188671, median: 37.166538763281
# min: 107, max: 255, mean: 190, median: 190
# for flight 70 and species 1:
# min: 26.87536231884058, max: 161.2015276145711, mean: 90.83016371007925, median: 91.39634888438134
# min: 8.94397835817998, max: 76.33653142808639, mean: 36.09117007595223, median: 35.8029807106514
# min: 64, max: 255, mean: 207, median: 213
# for flight 71 and species 1:
# min: 28.02186625985253, max: 172.55376344086022, mean: 90.42395571741481, median: 88.26906318082789
# min: 8.79520806914581, max: 87.37793664089976, mean: 34.29581804172428, median: 34.56126301246481
# min: 45, max: 255, mean: 202, median: 212
# for flight 72 and species 1:
# min: 11.215238095238096, max: 172.82686781609195, mean: 84.22925380292017, median: 84.897873834237
# min: 3.070333919016117, max: 78.88450638257315, mean: 35.068591708263256, median: 34.70281693763142
# min: 22, max: 255, mean: 199, median: 209.5
# for flight 74 and species 1:
# min: 18.129784688995215, max: 162.8716133004926, mean: 85.07882592640347, median: 84.39858806254597
# min: 9.533660987242513, max: 72.39957221166893, mean: 34.79067260132703, median: 34.525824197362994
# min: 75, max: 255, mean: 210, median: 217.0
# for flight 77 and species 3:
# min: 38.376451077943614, max: 165.3686274509804, mean: 96.35401249795213, median: 93.82235221674877
# min: 16.608120905754397, max: 73.60560406321262, mean: 46.39157295929099, median: 42.18836185788789
# min: 147, max: 255, mean: 220, median: 223
# for flight 78 and species 3:
# min: 0.0, max: 166.10700602079913, mean: 87.25553097174351, median: 86.05828571428572
# min: 0.0, max: 72.19066899966687, mean: 35.445294465313054, median: 34.12994076173725
# min: 0, max: 255, mean: 197, median: 201
# for flight 79 and species 3:
# min: 20.152542372881356, max: 148.75865051903114, mean: 84.75003937992102, median: 81.77135093167702
# min: 6.195222856134496, max: 76.0989754302679, mean: 38.26582048028494, median: 37.86428595028245
# min: 46, max: 255, mean: 207, median: 216.0
# for flight 80 and species 3:
# min: 19.35483870967742, max: 179.44027777777777, mean: 85.81951754837341, median: 79.96554923044486
# min: 10.551247648792966, max: 78.52595029781179, mean: 39.38830136481903, median: 39.701111082186834
# min: 54, max: 255, mean: 200, median: 209.0
# for flight 81 and species 3:
# min: 14.226969696969697, max: 170.69417833456154, mean: 105.42852033736341, median: 108.92724756006007
# min: 10.772045867361935, max: 81.0020499507191, mean: 42.02288617149753, median: 42.05743196594841
# min: 50, max: 255, mean: 197, median: 203.5
# for flight 82 and species 3:
# min: 20.43121442125237, max: 155.8088023088023, mean: 95.123777025182, median: 97.82431457431457
# min: 12.431724268504004, max: 75.70057547014781, mean: 41.87664768558436, median: 38.78187906648235
# min: 69, max: 255, mean: 205, median: 209
# for flight 83 and species 3:
# min: 32.17343976777939, max: 158.09191176470588, mean: 105.14320766079692, median: 105.2705518018018
# min: 14.21188794389222, max: 80.78839667875485, mean: 33.567185308710634, median: 28.351479241950614
# min: 68, max: 255, mean: 175, median: 184
# for flight 84 and species 1:
# min: 35.19345238095238, max: 171.57472222222222, mean: 118.08577616863215, median: 122.43114143920596
# min: 12.701768545094197, max: 80.01980341114404, mean: 35.682646631958946, median: 34.80889949326841
# min: 63, max: 255, mean: 196, median: 198
# for flight 85 and species 1:
# min: 26.55462365591398, max: 173.3105413105413, mean: 107.934301490768, median: 108.94714285714285
# min: 11.63190722367823, max: 89.06925035063837, mean: 38.65294078169929, median: 38.25017224386605
# min: 63, max: 255, mean: 200, median: 204
# for flight 86 and species 1:
# min: 0.09770114942528736, max: 172.78921023359288, mean: 96.33080656082272, median: 93.89778568638832
# min: 0.29691014604803423, max: 78.07200334505308, mean: 33.361728209798635, median: 32.66172976250698
# min: 1, max: 255, mean: 205, median: 209.0
# for flight 92 and species 3:
# min: 35.586559139784946, max: 171.94670406732118, mean: 101.55503140869445, median: 97.64493034055728
# min: 14.450062742485342, max: 91.08341429986835, mean: 34.62393231425286, median: 30.426665637906066
# min: 97, max: 255, mean: 200, median: 206
# for flight 93 and species 1:
# min: 21.86456605859591, max: 157.51819848127784, mean: 94.25300653603186, median: 98.00189837053294
# min: 6.781382004618607, max: 80.11275849136163, mean: 33.58429547507951, median: 33.507101769169715
# min: 40, max: 255, mean: 196, median: 197.0
# for flight 94 and species 0:
# min: 44.685428571428574, max: 122.32474600870827, mean: 85.14114248620336, median: 84.78628447024674
# min: 22.210932269326914, max: 59.52386953833165, mean: 31.760105416253776, median: 28.190328445497396
# min: 123, max: 255, mean: 185, median: 182
# for flight 94 and species 3:
# min: 50.795625942684765, max: 158.41552795031055, mean: 118.55496405266427, median: 126.39751475321765
# min: 26.642977889184902, max: 83.51898044762842, mean: 47.166928279667566, median: 39.013075420408576
# min: 149, max: 255, mean: 204, median: 210.5
# for flight 95 and species 3:
# min: 17.260526315789473, max: 144.93986175115208, mean: 94.1112643564152, median: 95.46466165413534
# min: 16.712712331486518, max: 71.49145474756881, mean: 37.568439739427674, median: 36.11836765968814
# min: 122, max: 255, mean: 214, median: 215
# for flight 96 and species 3:
# min: 0.0, max: 175.84181141439205, mean: 102.35978723462608, median: 102.83469458132149
# min: 0.0, max: 80.49216597835563, mean: 36.71777377351895, median: 34.78825051544286
# min: 0, max: 255, mean: 205, median: 204.0
# for flight 98 and species 3:
# min: 29.34408866995074, max: 112.98300492610838, mean: 85.75568333526307, median: 87.9185960591133
# min: 15.793545309098945, max: 49.313672983461615, mean: 30.671024109228874, median: 31.788765091917327
# min: 101, max: 251, mean: 185, median: 193.0
# for flight 99 and species 3:
# min: 32.44188861985472, max: 145.75869702719797, mean: 93.84123658993717, median: 96.14958886780519
# min: 6.604033719327239, max: 71.18273329778005, mean: 33.39807640976932, median: 36.692051741879375
# min: 46, max: 255, mean: 185, median: 190
# for flight 100 and species 3:
# min: 23.422456575682382, max: 145.42203548085902, mean: 94.98013914819393, median: 94.3588850174216
# min: 5.478079299825078, max: 79.00501776574413, mean: 32.64555896412686, median: 33.374339707476274
# min: 33, max: 255, mean: 194, median: 212
# for flight 101 and species 3:
# min: 1.1559322033898305, max: 144.83290598290597, mean: 95.69426523173661, median: 98.7528688825299
# min: 9.402366654585858, max: 78.14137824424016, mean: 40.358018782250646, median: 36.590091334328946
# min: 84, max: 255, mean: 212, median: 218.5
# for flight 102 and species 3:
# min: 8.410869565217391, max: 128.12161084529507, mean: 87.64928201518225, median: 91.01661367077655
# min: 12.079278401865283, max: 71.4096851879279, mean: 42.87337201094984, median: 44.08488243378313
# min: 82, max: 255, mean: 214, median: 216.5
# for flight 103 and species 3:
# min: 0.024444444444444446, max: 145.13584905660377, mean: 107.19491872487242, median: 107.72311890201883
# min: 0.1544244591385928, max: 75.70795392952081, mean: 34.837937097920445, median: 33.559883138653944
# min: 1, max: 255, mean: 178, median: 182.5
# for flight 104 and species 1:
# min: 50.779847756410255, max: 151.0946581196581, mean: 105.31029577250715, median: 101.51468253968254
# min: 9.233478839522338, max: 78.19079940274925, mean: 36.03237494377102, median: 36.35557439365517
# min: 52, max: 255, mean: 188, median: 188
# for flight 105 and species 1:
# min: 16.523809523809526, max: 175.40734603700636, mean: 112.54435196336222, median: 123.32859856764003
# min: 8.272936330704846, max: 84.55949771098977, mean: 33.52249745930481, median: 30.96554826659202
# min: 78, max: 255, mean: 196, median: 199.0
# for flight 106 and species 1:
# min: 20.403391768292682, max: 119.2384050717384, mean: 76.10864895134493, median: 78.4515720081136
# min: 10.409573527009602, max: 66.72158596950395, mean: 36.450430937502766, median: 38.81851283498864
# min: 63, max: 255, mean: 213, median: 221.0
# for flight 111 and species 3:
# min: 59.794285714285714, max: 141.26014254385964, mean: 86.1342861984851, median: 82.88450363196127
# min: 4.034969840825559, max: 63.75003933689543, mean: 18.915397550521597, median: 13.572471746782469
# min: 30, max: 236, mean: 137, median: 132
# for flight 112 and species 3:
# min: 16.33284023668639, max: 131.39054726368158, mean: 77.1284961525666, median: 75.63173838703074
# min: 4.480440608375279, max: 62.28918671088314, mean: 21.76523417059583, median: 17.081589974579273
# min: 31, max: 255, mean: 144, median: 144.5
# for flight 113 and species 3:
# min: 0.0027472527472527475, max: 102.94059116183787, mean: 76.4467555321096, median: 75.22248576850095
# min: 0.05234219473422432, max: 49.57664124518653, mean: 14.454448490291785, median: 10.264454331716184
# min: 1, max: 226, mean: 107, median: 98
# for flight 114 and species 3:
# min: 48.55416666666667, max: 105.26913345983554, mean: 72.45165397527703, median: 72.51270417422867
# min: 3.1603345179579927, max: 38.421175782527854, mean: 9.955501118723326, median: 7.270806687880198
# min: 25, max: 190, mean: 89, median: 83
# for flight 115 and species 3:
# min: 47.54813508064516, max: 133.57916666666668, mean: 80.10363222106137, median: 77.68446496212121
# min: 2.334173342216628, max: 40.39168478676638, mean: 16.300283960449757, median: 12.548241193859287
# min: 19, max: 241, mean: 124, median: 124.0
# for flight 116 and species 3:
# min: 35.39427083333333, max: 131.87457912457913, mean: 72.31420806342915, median: 69.72083333333333
# min: 3.0161052682321414, max: 45.930885054629556, mean: 13.633268428532462, median: 8.834398447677026
# min: 19, max: 255, mean: 108, median: 98
# for flight 117 and species 3:
# min: 32.63, max: 142.73191094619665, mean: 80.88452115816484, median: 78.375
# min: 2.478917286412087, max: 55.77882430272063, mean: 20.416500115437717, median: 15.135059101261628
# min: 15, max: 254, mean: 139, median: 137
# for flight 118 and species 3:
# min: 26.989724310776943, max: 134.83932291666667, mean: 76.00630534863183, median: 74.70194003527337
# min: 3.666121247079175, max: 59.79235890788556, mean: 19.086096244666717, median: 14.219257414871183
# min: 22, max: 255, mean: 135, median: 132
# for flight 119 and species 1:
# min: 30.435956790123456, max: 172.0659229208925, mean: 100.37403776957842, median: 96.81782464846981
# min: 2.4322364959250815, max: 78.12170359882327, mean: 16.357678004893693, median: 9.408877607726687
# min: 18, max: 255, mean: 121, median: 109
# for flight 120 and species 1:
# min: 41.02401026392962, max: 145.52662337662338, mean: 91.63709756633541, median: 86.30898491083676
# min: 2.0710472523463186, max: 77.75442358244892, mean: 15.455281721160196, median: 7.495060328230952
# min: 13, max: 255, mean: 105, median: 94
# for flight 121 and species 1:
# min: 31.144930875576037, max: 155.02648305084745, mean: 95.5237684716411, median: 91.1217390845828
# min: 2.3437980558474574, max: 67.97774110115186, mean: 17.397569420329173, median: 10.95560234163132
# min: 18, max: 254, mean: 121, median: 119.0
# for flight 122 and species 1:
# min: 27.402359781121753, max: 140.36482741244646, mean: 85.87892153251717, median: 85.97836812144213
# min: 1.9755016533557566, max: 76.0132019931974, mean: 16.91427087179266, median: 9.480310328060138
# min: 14, max: 255, mean: 121, median: 107
# for flight 123 and species 1:
# min: 22.707688528617048, max: 147.81539108494533, mean: 93.34938748647366, median: 92.95096279769555
# min: 2.7662281368422064, max: 77.0176794144588, mean: 23.659410729728776, median: 14.241570035241278
# min: 20, max: 255, mean: 137, median: 129.0
# for flight 124 and species 1:
# min: 51.122802041973905, max: 141.96796085858585, mean: 94.12774292585775, median: 90.30750630044342
# min: 2.034120293784047, max: 80.1427672535522, mean: 16.448181219981635, median: 9.74961029268088
# min: 14, max: 255, mean: 125, median: 110.0
# for flight 129 and species 1:
# min: 7.259267241379311, max: 117.13030888030887, mean: 83.38391204723152, median: 91.7512659210935
# min: 7.33056003462437, max: 61.07017716004114, mean: 23.172478804083166, median: 17.04346572374623
# min: 45, max: 185, mean: 97, median: 90.5
# for flight 130 and species 1:
# min: 8.882019704433498, max: 119.27288732394366, mean: 94.64642466667205, median: 105.97948717948718
# min: 23.780184280061846, max: 53.79527535220915, mean: 45.0449162540285, median: 46.52923005187714
# min: 190, max: 254, mean: 230, median: 231
# for flight 131 and species 1:
# min: 14.07136485280999, max: 127.99142156862744, mean: 87.51826532780868, median: 104.52843507483371
# min: 11.612221751086903, max: 60.229893354103964, mean: 41.88837513090995, median: 43.571685027098624
# min: 78, max: 255, mean: 226, median: 229.0
# for flight 132 and species 1:
# min: 0.0, max: 153.25496031746033, mean: 83.67942167508184, median: 91.68535714285714
# min: 0.0, max: 75.43797939074861, mean: 40.987556128661026, median: 42.10552339454165
# min: 0, max: 255, mean: 215, median: 231
# for flight 134 and species 3:
# min: 25.32483552631579, max: 94.11183597390495, mean: 62.670692271904954, median: 63.738538516204734
# min: 11.381836942307057, max: 53.46383542914682, mean: 29.773268451331035, median: 29.14160742686216
# min: 62, max: 187, mean: 134, median: 134.0
# for flight 134 and species 4:
# min: 15.608231707317072, max: 106.14605614973262, mean: 63.83624326812678, median: 63.608070500927646
# min: 16.63497882199323, max: 48.107870545409625, mean: 29.056944778138654, median: 27.949171024713078
# min: 74, max: 194, mean: 128, median: 122
# for flight 136 and species 3:
# min: 0.0, max: 118.61298076923077, mean: 74.29867534737839, median: 78.21140804597701
# min: 0.0, max: 50.588081492981054, mean: 26.18182633227672, median: 24.801326618674885
# min: 0, max: 209, mean: 115, median: 103.5
# for flight 136 and species 4:
# min: 32.53651115618661, max: 81.96162947937796, mean: 63.23921355531058, median: 63.0950605778192
# min: 19.54490781342133, max: 49.5032733060065, mean: 35.2761522089558, median: 35.95086106811973
# min: 105, max: 184, mean: 154, median: 155
# for flight 137 and species 3:
# min: 0.0, max: 185.44615384615383, mean: 94.7252221387175, median: 99.55550967615427
# min: 0.0, max: 88.80356370382174, mean: 30.390457902282407, median: 28.66795508318625
# min: 0, max: 219, mean: 138, median: 139.0
# for flight 137 and species 4:
# min: 36.01177536231884, max: 160.11111111111111, mean: 103.10085574658154, median: 91.28998786923822
# min: 20.48768783604057, max: 80.25371135306295, mean: 35.975525025596916, median: 34.42203410276255
# min: 109, max: 222, mean: 160, median: 172.0
# for flight 138 and species 3:
# min: 0.0, max: 180.7346782431052, mean: 109.32012528793071, median: 116.49448514134423
# min: 0.0, max: 84.50179617629381, mean: 37.22256886065808, median: 36.48200764111568
# min: 0, max: 239, mean: 163, median: 163.5
# for flight 139 and species 3:
# min: 11.248148148148148, max: 175.6682340647858, mean: 105.34722503229185, median: 109.49146063531039
# min: 15.761393955696343, max: 89.44806786252185, mean: 39.362163467613385, median: 35.706916040438
# min: 82, max: 239, mean: 168, median: 167.0
# for flight 139 and species 4:
# min: 43.01724137931034, max: 180.82511923688395, mean: 113.45475376013007, median: 118.06262946093455
# min: 18.002454250736655, max: 85.92341317962634, mean: 34.22744268533163, median: 32.29181677550376
# min: 111, max: 232, mean: 156, median: 154.5
# for flight 141 and species 3:
# min: 0.0, max: 181.94748622589532, mean: 111.74019385635835, median: 116.8493455861877
# min: 0.0, max: 81.26667172672106, mean: 36.07564839931866, median: 35.67017498514795
# min: 0, max: 255, mean: 186, median: 183
# for flight 141 and species 4:
# min: 36.255002128565344, max: 178.12533452274755, mean: 131.79468820836695, median: 132.3179472372302
# min: 13.9529833393051, max: 88.15705652517833, mean: 38.707957541979326, median: 36.8263389848221
# min: 100, max: 255, mean: 189, median: 207.0
# for flight 155 and species 1:
# min: 0.006801470588235294, max: 139.6953125, mean: 95.66080109703947, median: 98.78131306350684
# min: 0.08219008812547086, max: 62.16712998156763, mean: 19.93317908778233, median: 17.931754780512232
# min: 1, max: 178, mean: 101, median: 100.0
# for flight 156 and species 1:
# min: 18.689035916824196, max: 148.68363918325147, mean: 96.97160887688501, median: 99.33132620803853
# min: 5.641049616646484, max: 68.2700406232928, mean: 19.143125077192973, median: 16.683872782399288
# min: 39, max: 208, mean: 99, median: 93
# for flight 179 and species 3:
# min: 28.95405669599218, max: 124.24951124144673, mean: 74.90380292971052, median: 71.43859275053305
# min: 6.626345481705605, max: 48.26803840184434, mean: 25.900730599730586, median: 23.806529934709804
# min: 42, max: 255, mean: 164, median: 184
# for flight 180 and species 3:
# min: 24.651565464895636, max: 100.43845410628019, mean: 63.03991717166476, median: 60.1640625
# min: 6.994897896305651, max: 55.182364706532915, mean: 29.391153046072077, median: 26.865466369004103
# min: 70, max: 255, mean: 189, median: 210
# for flight 181 and species 3:
# min: 21.458150584795323, max: 98.05642276422765, mean: 71.52823290140945, median: 72.38296903460838
# min: 6.89142180732449, max: 47.35828045145215, mean: 24.37449768268003, median: 21.520021097678516
# min: 71, max: 255, mean: 170, median: 177
# for flight 182 and species 3:
# min: 23.25271002710027, max: 103.81639566395664, mean: 71.0993829004937, median: 71.59972969023963
# min: 4.284734173571197, max: 44.134231090994014, mean: 26.21788991788338, median: 25.123769529503967
# min: 27, max: 237, mean: 164, median: 174.0
# for flight 183 and species 3:
# min: 18.913806254767355, max: 102.5577731092437, mean: 65.98558665696355, median: 67.05636160714286
# min: 4.200494177747748, max: 51.50646644912133, mean: 24.2048265294556, median: 22.9955693523095
# min: 27, max: 255, mean: 169, median: 183
# for flight 184 and species 3:
# min: 18.163327120223673, max: 98.81574074074074, mean: 65.02512458395553, median: 64.1929181929182
# min: 6.324265361490559, max: 52.7968761324868, mean: 28.412530838605388, median: 26.622525704050428
# min: 46, max: 255, mean: 193, median: 209
# for flight 185 and species 3:
# min: 8.005750605326876, max: 97.60230024213075, mean: 52.40295667815774, median: 49.849804140406164
# min: 15.951508793531179, max: 76.83753697991547, mean: 44.52552672542324, median: 42.48521714847247
# min: 147, max: 255, mean: 229, median: 245.5
# for flight 186 and species 3:
# min: 7.408213096559378, max: 116.63766339869281, mean: 49.46468168677972, median: 48.82985541505278
# min: 15.459603704269707, max: 57.02673649507565, mean: 30.01685802028131, median: 28.77342548546452
# min: 109, max: 255, mean: 216, median: 225.0
# for flight 187 and species 3:
# min: 11.401553829078802, max: 97.35403050108933, mean: 44.47260938680413, median: 40.79114906832298
# min: 9.224574160584313, max: 68.63742270293882, mean: 35.22520542058695, median: 36.71474682248608
# min: 38, max: 255, mean: 223, median: 239.0
# for flight 188 and species 1:
# min: 68.65996398559423, max: 173.71547965116278, mean: 128.14339601494572, median: 121.54393424036282
# min: 28.058453175255675, max: 96.28217647550035, mean: 37.11903989273537, median: 34.44906466383663
# min: 177, max: 255, mean: 213, median: 206
# for flight 189 and species 1:
# min: 14.105999461931665, max: 174.7032786885246, mean: 119.98633257497923, median: 126.29790613352779
# min: 18.544540747400088, max: 83.1976661996447, mean: 37.3563383673539, median: 33.90158340577619
# min: 135, max: 255, mean: 203, median: 202.0
# for flight 190 and species 1:
# min: 50.238991596638655, max: 179.69635627530366, mean: 136.50767862200087, median: 140.6106013400689
# min: 14.778571407646677, max: 96.89560114260138, mean: 39.002688938984136, median: 31.828380929979318
# min: 124, max: 255, mean: 199, median: 182.0
# for flight 191 and species 1:
# min: 53.19907712590639, max: 167.5872736418511, mean: 133.40669397964783, median: 134.96052248461888
# min: 22.447429601547302, max: 74.52367107239232, mean: 36.02284102872068, median: 35.04500042272514
# min: 128, max: 255, mean: 193, median: 186.0
# for flight 192 and species 1:
# min: 42.359432571849666, max: 163.13420316868593, mean: 126.22667301832672, median: 133.47039455896754
# min: 18.662000905524653, max: 94.54813624576778, mean: 37.40853063507496, median: 32.79247713432538
# min: 133, max: 255, mean: 194, median: 186.0
# for flight 193 and species 1:
# min: 39.279091147885474, max: 165.91883372734438, mean: 108.64955968581666, median: 110.2654304029304
# min: 10.6113307132599, max: 78.49628225697239, mean: 39.34425875409662, median: 37.34796820630797
# min: 94, max: 255, mean: 212, median: 208.0
# for flight 194 and species 1:
# min: 35.047254901960784, max: 152.62573529411765, mean: 110.52954369268674, median: 114.56373176213606
# min: 11.171404952000609, max: 60.83654683972522, mean: 39.30074249728494, median: 36.93573313007958
# min: 56, max: 255, mean: 196, median: 190.5
# for flight 195 and species 1:
# min: 28.08814538043478, max: 137.67895400126025, mean: 99.54274850251838, median: 100.90865384615384
# min: 5.344372586104036, max: 61.72467805468491, mean: 40.7769814936011, median: 41.63930988116061
# min: 33, max: 255, mean: 202, median: 201
# for flight 196 and species 1:
# min: 15.224522659305268, max: 160.1006728778468, mean: 112.57156562751014, median: 115.54527664669683
# min: 6.377351731680889, max: 80.21778615721927, mean: 37.739160525340104, median: 35.34000307313812
# min: 64, max: 255, mean: 197, median: 191.0
# for flight 197 and species 1:
# min: 94.22306643288525, max: 159.13878256574887, mean: 133.36007272177955, median: 135.5152365359055
# min: 17.782637786128724, max: 66.94779178828041, mean: 38.40002458765671, median: 39.07950648794116
# min: 109, max: 255, mean: 210, median: 202.0
# for flight 198 and species 3:
# min: 39.57147425647585, max: 188.56311360448808, mean: 146.94115080655502, median: 153.23261858349576
# min: 20.845736354097923, max: 98.40432285879447, mean: 43.868279031149555, median: 38.458683290973106
# min: 128, max: 255, mean: 199, median: 192
# for flight 199 and species 3:
# min: 32.737266050698885, max: 161.4419018560895, mean: 103.81282560776012, median: 105.27054794520548
# min: 25.79124883674474, max: 60.69170112194631, mean: 39.52955794549626, median: 37.90428531584826
# min: 160, max: 255, mean: 210, median: 205
# for flight 201 and species 1:
# min: 18.764117647058825, max: 108.83108108108108, mean: 64.94785161100259, median: 64.9386126317439
# min: 3.2471667615792192, max: 75.70530315923689, mean: 36.25598522307364, median: 37.289573150413986
# min: 23, max: 255, mean: 210, median: 227.5
# for flight 202 and species 1:
# min: 20.020414523920834, max: 114.10105263157895, mean: 77.53882757405033, median: 79.47039897039897
# min: 2.889771666237607, max: 69.54939402624787, mean: 27.537845284810807, median: 25.11048253757166
# min: 17, max: 255, mean: 186, median: 200
# for flight 204 and species 1:
# min: 29.5890092879257, max: 99.16815666240953, mean: 68.73682360011298, median: 72.8298235221657
# min: 7.276494394112572, max: 70.92527757214452, mean: 38.7553039633505, median: 40.79641294937558
# min: 75, max: 255, mean: 211, median: 227.0
# for flight 205 and species 1:
# min: 21.90301724137931, max: 119.70051020408164, mean: 63.609334882000276, median: 59.23452518262207
# min: 6.852278827003542, max: 81.76044724117787, mean: 39.019283918926675, median: 39.388989565613386
# min: 37, max: 254, mean: 216, median: 231
# for flight 206 and species 1:
# min: 13.411024305555555, max: 110.35038363171356, mean: 61.571614563831346, median: 61.844482758620686
# min: 6.970005574925255, max: 81.66322732579671, mean: 43.6123096359164, median: 43.17746572200045
# min: 38, max: 255, mean: 224, median: 237.0
# for flight 210 and species 3:
# min: 38.823164682539684, max: 112.02244897959184, mean: 62.23222500438164, median: 56.965097080498865
# min: 9.081638066812191, max: 52.26698357206993, mean: 23.70526297192286, median: 25.079993918315672
# min: 58, max: 254, mean: 181, median: 183.0
# for flight 211 and species 1:
# min: 12.19472693032015, max: 114.66829109811566, mean: 43.4010645440119, median: 36.779080675422136
# min: 11.617398868249067, max: 66.82991105159394, mean: 38.606971014564344, median: 41.81079453715788
# min: 62, max: 255, mean: 233, median: 252
# for flight 212 and species 1:
# min: 15.961981566820276, max: 59.95226678291194, mean: 29.50149223189846, median: 22.63998366346743
# min: 19.739657660472627, max: 59.96123267455548, mean: 45.95575751839274, median: 47.75981263143124
# min: 182, max: 255, mean: 250, median: 254
# for flight 213 and species 1:
# min: 7.378378378378378, max: 162.68705270006507, mean: 80.1360271957089, median: 93.4888888888889
# min: 13.89164815136542, max: 81.33261741702381, mean: 44.82876238382856, median: 45.71802346115417
# min: 152, max: 255, mean: 229, median: 249
# for flight 215 and species 1:
# min: 13.550310559006212, max: 137.61590413943355, mean: 57.93594010197283, median: 47.4910437922733
# min: 9.49911454136318, max: 74.69124963055678, mean: 44.42581661549629, median: 45.262500600337646
# min: 125, max: 255, mean: 238, median: 254.5
# for flight 216 and species 3:
# min: 5.2604617604617605, max: 119.35817307692308, mean: 59.657531408418606, median: 64.13354700854701
# min: 11.037191923618211, max: 72.15082910288956, mean: 43.152320600612754, median: 44.82128215834154
# min: 179, max: 255, mean: 244, median: 255
# for flight 224 and species 0:
# min: 24.40727835849787, max: 170.13623188405796, mean: 102.30662896300782, median: 91.83739406779661
# min: 10.5850820063746, max: 77.45211045395504, mean: 31.710593234420113, median: 30.760776086274504
# min: 70, max: 251, mean: 173, median: 171
# for flight 225 and species 0:
# min: 24.437973484848484, max: 159.1987870619946, mean: 87.87941395634648, median: 91.7469521260779
# min: 22.758617936924175, max: 81.74289560167087, mean: 42.15840465539096, median: 41.996111053320945
# min: 144, max: 250, mean: 214, median: 220.0
# for flight 226 and species 0:
# min: 48.8172268907563, max: 144.16089466089466, mean: 112.19776055117755, median: 117.05824915824915
# min: 15.05888915976494, max: 48.620515036157606, mean: 22.146061968098312, median: 19.94220583779671
# min: 73, max: 148, mean: 105, median: 100
# for flight 227 and species 0:
# min: 45.74832623250152, max: 127.31395348837209, mean: 93.32460877478707, median: 94.54552374578199
# min: 10.832044534987597, max: 59.90003298636881, mean: 19.77023380858828, median: 17.788487396683472
# min: 64, max: 179, mean: 107, median: 106.0
# for flight 228 and species 0:
# min: 33.020388809862496, max: 138.3184065934066, mean: 96.92503363881934, median: 101.10290640817732
# min: 31.882445866198836, max: 77.59229503066476, mean: 47.887737931976375, median: 46.32835190513647
# min: 192, max: 255, mean: 241, median: 242.0
# for flight 229 and species 0:
# min: 2.1664626682986534, max: 147.15432098765433, mean: 51.680208375063714, median: 42.84712529079428
# min: 6.118611481302981, max: 78.39894203047031, mean: 42.011653955452296, median: 42.744162405458034
# min: 32, max: 255, mean: 238, median: 255
# for flight 230 and species 0:
# min: 12.641711229946525, max: 160.6453823953824, mean: 73.72691118534597, median: 70.52606358111267
# min: 20.178201233847993, max: 76.74369197363663, mean: 42.70232842499097, median: 41.837326781272125
# min: 136, max: 255, mean: 241, median: 246.0
# for flight 231 and species 3:
# min: 28.204144620811288, max: 160.38093023255814, mean: 108.67760488540523, median: 109.29542151162791
# min: 20.619755164551076, max: 71.07262520727816, mean: 35.31095427608558, median: 34.31348498683316
# min: 156, max: 255, mean: 208, median: 200.0
# for flight 232 and species 3:
# min: 17.501984126984127, max: 172.39767573696145, mean: 99.96254541895563, median: 99.7209595959596
# min: 13.736187418734561, max: 78.9559626745518, mean: 38.6608212309196, median: 37.15256387089456
# min: 92, max: 255, mean: 210, median: 217
# for flight 234 and species 3:
# min: 23.891578947368423, max: 143.88667232597624, mean: 88.5437140858137, median: 88.07577235772358
# min: 9.334805568092014, max: 73.86892455196683, mean: 33.27507812037395, median: 30.08205543526899
# min: 72, max: 255, mean: 205, median: 206
# for flight 235 and species 3:
# min: 41.592927631578945, max: 153.20528280218204, mean: 97.41520543986081, median: 103.42856338166143
# min: 11.935554102213462, max: 69.92354107883637, mean: 32.94559016653225, median: 32.36676793698444
# min: 85, max: 255, mean: 186, median: 189.5
# for flight 236 and species 1:
# min: 16.542524005486968, max: 170.54538461538462, mean: 108.19511226299417, median: 107.16760204081632
# min: 4.7203028831444085, max: 81.93158030981174, mean: 30.731741489164833, median: 28.386962606180077
# min: 57, max: 255, mean: 175, median: 179.5
# for flight 237 and species 1:
# min: 20.797863710113575, max: 161.77085714285715, mean: 107.00544522339723, median: 105.53506552032776
# min: 9.057275252291577, max: 77.56914966945413, mean: 32.15070286188548, median: 27.33565356181073
# min: 103, max: 255, mean: 197, median: 195.5
# for flight 238 and species 1:
# min: 16.999438832772167, max: 160.06041055718475, mean: 98.59981492182172, median: 97.58250526949713
# min: 5.887449389282045, max: 76.07536628504705, mean: 30.27023126164091, median: 29.68050811116093
# min: 41, max: 255, mean: 180, median: 187
# for flight 239 and species 1:
# min: 24.05068181818182, max: 138.17768762677485, mean: 92.22566453349984, median: 94.8928409090909
# min: 5.8572699582344985, max: 65.79680227641877, mean: 24.87119102142091, median: 21.339932485378327
# min: 40, max: 255, mean: 154, median: 159.5
# for flight 240 and species 1:
# min: 25.91403926234384, max: 149.75928961748633, mean: 100.70902450255596, median: 101.82424242424243
# min: 12.569353155686372, max: 63.0116688969789, mean: 33.97256946649826, median: 33.18065550806127
# min: 135, max: 255, mean: 200, median: 204
# for flight 241 and species 1:
# min: 16.713553979511428, max: 156.96950146627566, mean: 90.92204317758011, median: 83.68887147335423
# min: 6.916604345856792, max: 76.47359518346516, mean: 25.678442104533485, median: 24.554156443247155
# min: 48, max: 255, mean: 157, median: 153
# for flight 242 and species 1:
# min: 23.161458333333332, max: 126.29728395061728, mean: 76.46800175290278, median: 79.58866666666667
# min: 8.598673313843996, max: 72.91372510235394, mean: 28.851062473567673, median: 23.38573806964303
# min: 55, max: 255, mean: 175, median: 181
# for flight 243 and species 3:
# min: 18.3024, max: 148.00343118566528, mean: 79.5478728973519, median: 76.92471042471043
# min: 7.969787697707528, max: 76.20380916632185, mean: 31.491549844003718, median: 30.044226514277398
# min: 87, max: 255, mean: 187, median: 189
# for flight 244 and species 3:
# min: 14.031919850885368, max: 175.03333333333333, mean: 75.68828241615914, median: 74.78439291101057
# min: 10.567369149217873, max: 76.32899948708109, mean: 34.117310165234194, median: 34.247024459847395
# min: 67, max: 255, mean: 199, median: 209.5
# for flight 245 and species 3:
# min: 10.479611190137506, max: 119.8798196517413, mean: 71.39139747381003, median: 74.78136169942726
# min: 12.361693419291845, max: 56.537254728291465, mean: 33.827286520598356, median: 33.22899259892253
# min: 84, max: 255, mean: 207, median: 222.5
# for flight 246 and species 3:
# min: 23.930113636363636, max: 119.46938775510205, mean: 90.74057946216993, median: 91.94783590360309
# min: 19.51510804487749, max: 65.97762505313806, mean: 36.49734444722106, median: 36.085949107955415
# min: 106, max: 243, mean: 172, median: 172.0
# for flight 246 and species 4:
# min: 26.62684659090909, max: 128.51078431372548, mean: 90.08698053954404, median: 89.26314268577427
# min: 24.29218875482901, max: 64.52078089569153, mean: 37.77357163783344, median: 36.259995113329715
# min: 99, max: 244, mean: 174, median: 170.0
# for flight 247 and species 0:
# min: 22.03662222222222, max: 133.3968253968254, mean: 84.69299917196608, median: 86.42740270350563
# min: 13.110741798624671, max: 59.88375443150616, mean: 31.600595089940626, median: 31.568469240271625
# min: 80, max: 200, mean: 156, median: 161.0
# for flight 248 and species 1:
# min: 6.526864035087719, max: 177.17267759562841, mean: 108.54986925465353, median: 113.90802986816227
# min: 18.489649837967086, max: 89.69449053547548, mean: 56.84690858845294, median: 55.421806023240165
# min: 105, max: 255, mean: 241, median: 247.5
# for flight 249 and species 1:
# min: 23.30372549019608, max: 149.06196823596142, mean: 101.07641404800347, median: 101.35358024691358
# min: 38.714952599069186, max: 98.2991161653734, mean: 69.95539230165848, median: 71.632290858453
# min: 252, max: 255, mean: 254, median: 255
# for flight 251 and species 1:
# min: 20.084722222222222, max: 127.32973345588235, mean: 75.36501089733102, median: 71.84780682321666
# min: 24.804274735568015, max: 75.29919823135239, mean: 50.22944611840097, median: 48.60041345127126
# min: 169, max: 255, mean: 246, median: 255
# for flight 256 and species 3:
# min: 31.36004784688995, max: 173.19565217391303, mean: 96.1928087686863, median: 97.18540669856459
# min: 18.09486649022717, max: 73.41027747612115, mean: 32.38417021855837, median: 27.751768261980473
# min: 137, max: 255, mean: 192, median: 187
# for flight 295 and species 0:
# min: 39.98115079365079, max: 137.23281596452327, mean: 75.95246358145953, median: 73.3955965909091
# min: 2.711928893912718, max: 56.2100584794669, mean: 22.839567486275985, median: 26.394445527234655
# min: 17, max: 255, mean: 154, median: 194
# for flight 301 and species 0:
# min: 45.751736111111114, max: 72.66319444444444, mean: 59.43587078374371, median: 59.000828912466844
# min: 1.1445054911408434, max: 14.74190857552149, mean: 6.932537741202603, median: 6.562339654343705
# min: 9, max: 198, mean: 87, median: 76.0
# for flight 302 and species 0:
# min: 45.696507936507935, max: 74.89725378787878, mean: 59.81363464792447, median: 60.232247284878866
# min: 2.217816391747518, max: 40.88317822631648, mean: 12.516524749816648, median: 12.161467887725452
# min: 15, max: 240, mean: 140, median: 167
# for flight 304 and species 0:
# min: 48.979223619464186, max: 74.71929824561404, mean: 57.977989695888866, median: 56.69879260812175
# min: 2.1468712696811285, max: 17.102196726902548, mean: 9.775045869419976, median: 9.339921534150678
# min: 17, max: 200, mean: 134, median: 155.5
# for flight 347 and species 0:
# min: 20.975326560232222, max: 112.47881355932203, mean: 61.09391112402514, median: 49.49964387464387
# min: 30.826698052936422, max: 74.4957433238479, mean: 48.803684179762286, median: 48.1581001858845
# min: 224, max: 255, mean: 253, median: 255
# for flight 348 and species 0:
# min: 33.629714285714286, max: 81.77443609022556, mean: 53.90723892771147, median: 51.97049071618037
# min: 17.948537301717206, max: 64.80773203273004, mean: 31.693376324878926, median: 29.023774174750926
# min: 194, max: 255, mean: 236, median: 250
# for flight 349 and species 0:
# min: 12.631227529532614, max: 154.25025025025025, mean: 89.23760069007258, median: 90.91778795416855
# min: 10.866953365193094, max: 87.52194889998812, mean: 53.049566984832744, median: 54.87273533546805
# min: 167, max: 255, mean: 246, median: 255.0

# %%
calc_flight_stats(flight_val, y_val, X_val, "val")
# Out:
# val flight ids + statistic
# for flight 6 and species 1:
# min: 0.008812260536398468, max: 119.75541299117883, mean: 82.9189712428312, median: 86.27121350940692
# min: 0.09941845848731222, max: 81.5263548786059, mean: 42.4435204611765, median: 40.974805433467694
# min: 2, max: 255, mean: 226, median: 230.0
# for flight 10 and species 1:
# min: 0.0015250544662309367, max: 125.7855464159812, mean: 79.43954415976786, median: 84.20205173951828
# min: 0.039022156207800286, max: 62.5800321287395, mean: 26.026398288309522, median: 25.331528301453513
# min: 1, max: 255, mean: 181, median: 196
# for flight 13 and species 1:
# min: 10.967647058823529, max: 108.20051914341337, mean: 63.20691252082045, median: 65.66939293453567
# min: 3.483245399322988, max: 74.3879074040369, mean: 46.726711554307414, median: 46.71306066553147
# min: 25, max: 255, mean: 235, median: 243.0
# for flight 14 and species 1:
# min: 0.0, max: 141.94509803921568, mean: 75.89041752929585, median: 75.97252747252747
# min: 0.0, max: 82.37879521162765, mean: 49.69945517069063, median: 47.017065266486696
# min: 0, max: 255, mean: 229, median: 240
# for flight 15 and species 1:
# min: 0.0, max: 170.04304245283018, mean: 89.832297103426, median: 87.47967686155147
# min: 0.0, max: 91.26650727352832, mean: 56.42247848480745, median: 56.8421897246756
# min: 0, max: 255, mean: 232, median: 243.5
# for flight 22 and species 1:
# min: 16.814732142857142, max: 110.35212053571429, mean: 70.29322028257769, median: 68.72407834101382
# min: 3.207509307842271, max: 55.55823162033906, mean: 14.25695249049979, median: 12.490055878084338
# min: 27, max: 249, mean: 145, median: 155
# for flight 56 and species 0:
# min: 0.0, max: 102.58731290092659, mean: 74.76889113623552, median: 76.88417832167832
# min: 0.0, max: 48.75123253681385, mean: 18.11216756167031, median: 17.26673855153603
# min: 0, max: 216, mean: 133, median: 136
# for flight 57 and species 0:
# min: 0.0, max: 114.1604872881356, mean: 71.78319791851658, median: 77.24229459344402
# min: 0.0, max: 49.363593007093584, mean: 23.68455357264322, median: 22.66001298281997
# min: 0, max: 245, mean: 150, median: 150.0
# for flight 66 and species 1:
# min: 28.08813160987074, max: 134.64806110458284, mean: 62.88430394005544, median: 57.66699507389163
# min: 27.14685075600444, max: 48.60751644491294, mean: 36.005667348768, median: 35.490508098124835
# min: 116, max: 249, mean: 205, median: 214.5
# for flight 142 and species 3:
# min: 30.469727403156384, max: 166.94249512670567, mean: 111.81929520901909, median: 110.9319248826291
# min: 20.666259154083622, max: 74.54594557602157, mean: 38.383533375019695, median: 34.94123130661868
# min: 104, max: 255, mean: 196, median: 191
# for flight 142 and species 4:
# min: 23.18185483870968, max: 139.73508230452674, mean: 104.29077704864815, median: 108.01391129032258
# min: 27.398253010242247, max: 69.88437484032774, mean: 39.69210132840004, median: 36.05375817659948
# min: 108, max: 255, mean: 196, median: 190
# for flight 143 and species 1:
# min: 23.595799557848196, max: 165.2453399122807, mean: 80.95323520552674, median: 75.36160714285714
# min: 33.27616956047007, max: 89.12470660062101, mean: 71.18423737802034, median: 72.61381014132563
# min: 240, max: 255, mean: 254, median: 255
# for flight 143 and species 2:
# min: 11.511688311688312, max: 127.14439853076216, mean: 60.47526887273412, median: 54.37250525210084
# min: 19.51944185981217, max: 87.59918742870005, mean: 55.86121917634923, median: 55.87782763605719
# min: 210, max: 255, mean: 254, median: 255.0
# for flight 150 and species 0:
# min: 41.01464536431857, max: 99.70324074074074, mean: 80.42397473568602, median: 83.45098765432098
# min: 7.955118193898839, max: 53.07856700991712, mean: 21.25287238939505, median: 15.224589077797537
# min: 56, max: 222, mean: 131, median: 135
# for flight 175 and species 1:
# min: 45.82915758896151, max: 120.4237012987013, mean: 95.46775661355113, median: 97.41110475464023
# min: 6.5075163386222385, max: 67.3623628148343, mean: 24.260561671524915, median: 22.433935349498505
# min: 47, max: 175, mean: 106, median: 103.0
# for flight 176 and species 1:
# min: 39.977871939736346, max: 135.2745978301534, mean: 87.73252111536142, median: 91.16581196581197
# min: 36.66988877180121, max: 93.0632969727015, mean: 61.277674456912806, median: 61.4868982109557
# min: 187, max: 255, mean: 235, median: 253
# for flight 177 and species 1:
# min: 15.479934210526316, max: 117.89332003988036, mean: 64.50660685224607, median: 71.62168458781362
# min: 27.196874323148922, max: 80.15502310969927, mean: 51.089253313333444, median: 52.691686795757136
# min: 168, max: 255, mean: 240, median: 244
# for flight 178 and species 1:
# min: 21.541176470588237, max: 129.77775621118013, mean: 85.79524053624833, median: 84.67207074428887
# min: 10.98728661992497, max: 79.51908693362265, mean: 51.06093523021502, median: 50.62898896917238
# min: 89, max: 255, mean: 220, median: 216
# for flight 221 and species 0:
# min: 13.916564039408867, max: 98.21271008403362, mean: 66.71502446755815, median: 70.27431476569407
# min: 1.7896399413183468, max: 51.711631826038634, mean: 20.4686311458729, median: 20.69783764651408
# min: 12, max: 224, mean: 125, median: 144
# for flight 222 and species 0:
# min: 14.183193946634807, max: 112.25294117647059, mean: 74.63502404644484, median: 80.54539695945945
# min: 16.057159103574598, max: 56.8924383815111, mean: 30.668537034758607, median: 28.44674895259461
# min: 127, max: 254, mean: 194, median: 197
# for flight 223 and species 0:
# min: 9.024072966507177, max: 126.63383838383838, mean: 77.79267475464577, median: 79.60547041294167
# min: 13.667113662128788, max: 65.9379796519286, mean: 35.36420816144925, median: 33.85669125131539
# min: 120, max: 255, mean: 218, median: 219

# %%
calc_flight_stats(flight_test, y_test, X_test, "test")
# Out:
# test flight ids + statistic
# for flight 55 and species 1:
# min: 0.0, max: 176.8071278825996, mean: 88.87445155540726, median: 91.31868721461188
# min: 0.0, max: 100.75778592299407, mean: 49.13209757172988, median: 48.41042662584232
# min: 0, max: 255, mean: 220, median: 222.0
# for flight 135 and species 3:
# min: 11.876373626373626, max: 129.30042016806723, mean: 76.55071600165472, median: 76.0450070323488
# min: 5.8956461108162195, max: 63.12082221014258, mean: 33.20186304096701, median: 35.43576824316273
# min: 45, max: 190, mean: 134, median: 145
# for flight 135 and species 4:
# min: 48.37488947833776, max: 102.14414414414415, mean: 68.90809304740299, median: 63.580271703581545
# min: 18.00086634475906, max: 50.15532185041242, mean: 33.87246854829602, median: 34.03963243914531
# min: 79, max: 177, mean: 140, median: 147.0
# for flight 140 and species 3:
# min: 0.0, max: 171.0223978919631, mean: 107.46831161243936, median: 121.63672683231755
# min: 0.0, max: 97.6716790376414, mean: 37.02904599537662, median: 36.345096720099576
# min: 0, max: 255, mean: 187, median: 184.0
# for flight 140 and species 4:
# min: 58.9930426716141, max: 161.4590367428004, mean: 128.21127835935238, median: 125.1153109097814
# min: 22.099072581889352, max: 71.54241930555636, mean: 36.35677154089553, median: 35.5246085185302
# min: 140, max: 255, mean: 180, median: 177.5
# for flight 152 and species 1:
# min: 0.0037546933667083854, max: 100.95061728395062, mean: 85.21869449756409, median: 87.6217722696777
# min: 0.06366699897374421, max: 47.324320274314445, mean: 11.207722446245898, median: 8.428305670049433
# min: 2, max: 120, mean: 54, median: 50.5
# for flight 159 and species 1:
# min: 42.38941598144634, max: 133.3815015015015, mean: 85.01580943359221, median: 86.97252321981424
# min: 25.053563808575294, max: 87.8504567622501, mean: 50.52438715522495, median: 47.77390765715598
# min: 215, max: 255, mean: 245, median: 251
# for flight 160 and species 1:
# min: 17.43110314615691, max: 80.62056173820879, mean: 52.473051109472244, median: 55.07352941176471
# min: 16.215389347526248, max: 50.00085044339627, mean: 33.01818774668025, median: 32.85532315398902
# min: 124, max: 255, mean: 229, median: 242.5
# for flight 161 and species 1:
# min: 0.00636574074074074, max: 207.26129032258063, mean: 102.32597643489133, median: 89.54030501089325
# min: 0.07953123968329939, max: 102.69953464940129, mean: 38.933602097425776, median: 36.82149512454412
# min: 1, max: 255, mean: 226, median: 238
# for flight 162 and species 1:
# min: 16.01716247139588, max: 129.36335784313727, mean: 63.723109418472056, median: 62.906597222222224
# min: 17.084882053916562, max: 77.98111322822791, mean: 42.478587759885876, median: 38.80553261228908
# min: 124, max: 255, mean: 237, median: 251
# for flight 163 and species 1:
# min: 0.0, max: 209.17277777777778, mean: 98.28774263872975, median: 85.89556513398247
# min: 0.0, max: 100.12315945393998, mean: 46.51668835189861, median: 45.884504500762375
# min: 0, max: 255, mean: 234, median: 250.0
# for flight 250 and species 1:
# min: 16.689733593242366, max: 153.29707532051282, mean: 100.24493151515081, median: 100.89250905040379
# min: 27.805691796650216, max: 92.3468712329589, mean: 70.30049346660505, median: 72.34107337837517
# min: 247, max: 255, mean: 254, median: 255
# for flight 252 and species 1:
# min: 17.205510204081634, max: 161.38523644752019, mean: 77.81939439027536, median: 75.35602268935602
# min: 26.34652148059487, max: 77.32893539052668, mean: 51.1441453627717, median: 50.12322846969914
# min: 186, max: 255, mean: 252, median: 255
# for flight 260 and species 0:
# min: 9.470965309200603, max: 133.52745098039216, mean: 47.231068753977105, median: 41.15056818181818
# min: 13.680827398005606, max: 74.95629620350041, mean: 33.21463805636171, median: 31.475965776129293
# min: 72, max: 255, mean: 224, median: 239
# for flight 261 and species 0:
# min: 5.223622782446312, max: 106.81094182825485, mean: 56.67449120361294, median: 52.594919786096256
# min: 9.24405061027297, max: 53.24437397231857, mean: 26.816170986464535, median: 26.241276316651923
# min: 57, max: 255, mean: 189, median: 204
# for flight 262 and species 0:
# min: 0.4985294117647059, max: 163.8, mean: 91.21437915412056, median: 89.93140096618357
# min: 4.475751420549035, max: 77.78071891822007, mean: 52.06335776650593, median: 52.68822153059705
# min: 61, max: 255, mean: 247, median: 255
# for flight 263 and species 0:
# min: 4.7603121516165, max: 155.6374362244898, mean: 69.36255151172743, median: 54.93440645773979
# min: 9.762706730816301, max: 80.31218824367573, mean: 39.07208082375827, median: 37.5157686503986
# min: 104, max: 255, mean: 227, median: 241.0
# for flight 264 and species 0:
# min: 13.190740740740742, max: 154.09857549857549, mean: 81.54021190107007, median: 79.87954545454545
# min: 8.954583900969725, max: 87.59583968027694, mean: 31.01144775850723, median: 29.272462441667493
# min: 81, max: 255, mean: 187, median: 184
# for flight 265 and species 0:
# min: 9.35763888888889, max: 73.18790218790218, mean: 30.20583843957081, median: 25.5757385292269
# min: 10.72302268027624, max: 55.49300008357943, mean: 29.277084989369676, median: 27.334243375983537
# min: 97, max: 255, mean: 222, median: 234
# for flight 266 and species 0:
# min: 44.35914855072464, max: 142.04291666666666, mean: 80.01854323800234, median: 70.27966457023061
# min: 7.790447665339194, max: 66.51575869063144, mean: 36.22872600071997, median: 34.85671302327794
# min: 57, max: 244, mean: 201, median: 225
# for flight 276 and species 3:
# min: 27.66184210526316, max: 210.4376863446631, mean: 141.40918210998802, median: 150.18632711705374
# min: 9.054207186475507, max: 103.97109537665972, mean: 38.563951531565564, median: 31.01822016937752
# min: 77, max: 255, mean: 188, median: 187.0
# for flight 277 and species 3:
# min: 55.23224431818182, max: 206.48739495798318, mean: 161.73134235918346, median: 167.1164274322169
# min: 9.54387128450606, max: 99.48214177944095, mean: 32.4523988681542, median: 23.968529338985213
# min: 72, max: 255, mean: 157, median: 139
# for flight 278 and species 3:
# min: 6.668571428571428, max: 139.81058823529412, mean: 80.26819914907877, median: 92.45892857142857
# min: 6.442429708294995, max: 71.30423423447006, mean: 35.01842126460581, median: 34.93324709753987
# min: 116, max: 255, mean: 216, median: 215
# for flight 279 and species 3:
# min: 49.39480800432666, max: 199.9068287037037, mean: 140.81973028047213, median: 137.10506844247132
# min: 8.691185267621544, max: 89.7516662721282, mean: 37.34711217089839, median: 35.6515744251078
# min: 73, max: 255, mean: 198, median: 204
# for flight 280 and species 3:
# min: 64.02462887989203, max: 199.65268065268066, mean: 140.40050499018295, median: 140.38553113553112
# min: 2.1402218305795957, max: 104.30924051765166, mean: 34.92754467014624, median: 32.12105952731995
# min: 12, max: 255, mean: 176, median: 168
# for flight 281 and species 3:
# min: 20.288533834586467, max: 180.23996655518394, mean: 87.89005566934422, median: 74.46637190530511
# min: 3.327411450001593, max: 99.8064095477227, mean: 29.551327891995793, median: 28.403287210962027
# min: 21, max: 255, mean: 178, median: 192.5
# for flight 282 and species 3:
# min: 35.21895424836601, max: 198.94725177304966, mean: 140.2026513714953, median: 147.0029268292683
# min: 12.317498607809533, max: 103.54354643252486, mean: 35.471973081926826, median: 28.99311033421432
# min: 89, max: 255, mean: 179, median: 172
# for flight 283 and species 3:
# min: 30.510416666666668, max: 211.2716049382716, mean: 151.34998250365229, median: 164.24770814490043
# min: 8.926473811875203, max: 97.93966424493179, mean: 34.728582598209705, median: 30.57472683586642
# min: 75, max: 255, mean: 162, median: 151.0
# for flight 284 and species 3:
# min: 18.256805807622506, max: 205.0648148148148, mean: 135.0963354446641, median: 149.17280606717227
# min: 8.672330078997323, max: 102.19293345504936, mean: 39.28643058305538, median: 33.537539768806084
# min: 76, max: 255, mean: 185, median: 188
# for flight 296 and species 0:
# min: 33.11822222222222, max: 84.88103756708408, mean: 67.17421834776142, median: 71.03187882189249
# min: 4.461716305981559, max: 26.84467139781099, mean: 12.644529105278085, median: 11.627950673562456
# min: 26, max: 198, mean: 100, median: 86.0
# for flight 297 and species 0:
# min: 48.8525641025641, max: 106.73991817650497, mean: 76.4930845118125, median: 74.5147209421403
# min: 5.908351481229531, max: 42.03384778392581, mean: 16.58076399223304, median: 14.738188238284287
# min: 38, max: 206, mean: 128, median: 129.0
# for flight 298 and species 0:
# min: 41.93824404761905, max: 133.67237103174602, mean: 77.00085985287961, median: 75.3071253071253
# min: 4.33853607301188, max: 42.79348042542092, mean: 16.71036960995875, median: 11.277771916683502
# min: 42, max: 255, mean: 119, median: 119
# for flight 299 and species 0:
# min: 41.74337923728814, max: 143.59622367465505, mean: 69.00832044646835, median: 52.91132428332287
# min: 2.2788210769830313, max: 31.617357269416004, mean: 14.069455835912104, median: 12.750974320288098
# min: 14, max: 207, mean: 117, median: 133.0
# for flight 300 and species 0:
# min: 31.804600484261503, max: 81.51511111111111, mean: 63.11421301074891, median: 62.92934362934363
# min: 2.819906736590931, max: 36.889460270891405, mean: 12.05330327027442, median: 11.29848290089617
# min: 20, max: 221, mean: 136, median: 167
# for flight 303 and species 0:
# min: 50.82166199813258, max: 84.26089743589743, mean: 76.70155729093828, median: 78.18043884220356
# min: 2.2451061199443583, max: 43.42102673249297, mean: 11.476000954556673, median: 9.572647707633372
# min: 17, max: 190, mean: 86, median: 88.5
# for flight 308 and species 0:
# min: 46.24940476190476, max: 100.9005690326445, mean: 61.92647421547185, median: 58.68069007263922
# min: 2.7407816481494507, max: 56.61093461138285, mean: 13.165222061184975, median: 11.460529307632514
# min: 21, max: 253, mean: 143, median: 157
# for flight 309 and species 0:
# min: 17.77705223880597, max: 92.3442118226601, mean: 62.425575443862705, median: 61.56394453004623
# min: 3.6494628717479216, max: 51.24664282514, mean: 17.94814393815991, median: 14.524947208684171
# min: 32, max: 253, mean: 146, median: 157
# for flight 314 and species 0:
# min: 17.806163594470046, max: 120.44958333333334, mean: 59.12552777896491, median: 51.67880747126436
# min: 7.405099431585071, max: 70.0511493249684, mean: 39.99229270368678, median: 35.01457697376286
# min: 82, max: 255, mean: 233, median: 237.5
# for flight 343 and species 0:
# min: 19.361290322580643, max: 114.86418604651163, mean: 65.07421642358327, median: 65.12435897435897
# min: 4.244969856100313, max: 54.68293306844271, mean: 28.65000398421787, median: 26.788517372907158
# min: 44, max: 255, mean: 199, median: 212

# %%
imgs = [
    img for img, f, y in zip(X_val, flight_val, y_val)
    if int(f) == 143 and y == 1
]

fig, axs = plt.subplots(4, 4, figsize=(10, 10))

for ax, img in zip(axs.flat, imgs[:16]):
    ax.imshow(img, cmap="gray")
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
# comparing different flights, same species (Red Deers)
for flight in [15, 22, 143, 176]:

    imgs = [
        img for img, f, y in zip(X_val, flight_val, y_val)
        if int(f) == flight and y == 1
    ]

    fig, axs = plt.subplots(1, 5, figsize=(12, 3))

    for ax, img in zip(axs, imgs[:5]):
        ax.imshow(img, cmap="gray")
        ax.axis("off")

    plt.suptitle(f"Flight {flight}")
    plt.show()

# %%
train_bright = [np.array(img).mean() for img in X_train]
val_bright = [np.array(img).mean() for img in X_val]
test_bright = [np.array(img).mean() for img in X_test]

fig, ax = plt.subplots(1, 3, figsize=(12, 4))

ax[0].hist(train_bright, bins=40)
ax[0].set_title(f"Brightness of train dataset")

ax[1].hist(val_bright, bins=40)
ax[1].set_title(f"Brightness of val dataset")

ax[2].hist(test_bright, bins=40)
ax[2].set_title(f"Brightness of test dataset")
plt.show()

# %%
train_contrast = [np.array(img).std() for img in X_train]
val_contrast = [np.array(img).std() for img in X_val]
test_constrast = [np.array(img).std() for img in X_test]

fig, ax = plt.subplots(1, 3, figsize=(12, 4))

ax[0].hist(train_contrast, bins=40)
ax[0].set_title(f"Constrast of train dataset")

ax[1].hist(val_contrast, bins=40)
ax[1].set_title(f"Constrast of val dataset")

ax[2].hist(test_constrast, bins=40)
ax[2].set_title(f"Constrast of test dataset")
plt.show()

# %%
train_range = [np.array(img).max() - np.array(img).min() for img in X_train]
val_range = [np.array(img).max() - np.array(img).min() for img in X_val]
test_range = [np.array(img).max() - np.array(img).min() for img in X_test]

fig, ax = plt.subplots(1, 3, figsize=(12, 4))

ax[0].hist(train_contrast, bins=40)
ax[0].set_title(f"Range of train dataset")

ax[1].hist(val_contrast, bins=40)
ax[1].set_title(f"Range of val dataset")

ax[2].hist(test_constrast, bins=40)
ax[2].set_title(f"Range of test dataset")
plt.show()

# %%
X = X_train + X_val + X_test
flight_ids = flight_train + flight_val + flight_test
labels = y_train + y_val + y_test

# %%
brightnesses1 = [np.array(img).mean()
    for img, f, y in zip(X, flight_ids, labels)
    if int(f) == 15 and y == 1]

brightnesses2 = [np.array(img).mean()
    for img, f, y in zip(X, flight_ids, labels)
    if int(f) == 22 and y == 1]

brightnesses3 = [np.array(img).mean()
    for img, f, y in zip(X, flight_ids, labels)
    if int(f) == 143 and y == 1]

brightnesses4 = [np.array(img).mean()
    for img, f, y in zip(X, flight_ids, labels)
    if int(f) == 176 and y == 1]

fig, ax = plt.subplots(2, 2, figsize=(8, 8))
ax[0, 0].hist(brightnesses1, bins=40)
ax[0, 0].set_title("Flight 15, species 1")
ax[0, 1].hist(brightnesses2, bins=40)
ax[0, 1].set_title("Flight 22, species 1")
ax[1, 0].hist(brightnesses3, bins=40)
ax[1, 0].set_title("Flight 143, species 1")
ax[1, 1].hist(brightnesses4, bins=40)
ax[1, 1].set_title("Flight 176, species 1")
plt.show()

# %% [markdown]
# ## Investigating Black Images (Noise)
#
# I found out that some images are completely black (std==0 and/or range==0)

# %%
bad = 0 # bad images are image crops that are completely black

for img in X:
    arr = np.asarray(img)
    if arr.std() == 0:
        bad += 1

print(bad)
print(bad / len(X)) # luckily only 59 out of the whole dataset -> we can neglect that fact, esp. as it only affects very few img per flight and species
# Out:
# 59
# 0.0014361171287393813

# %%
counter = Counter()
for img, fid, y in zip(X, flight_ids, labels):

    arr = np.asarray(img)

    if arr.std() == 0:
        counter[(fid, y)] += 1

print(counter)
# Out:
# Counter({('17', 2): 13, ('132', 1): 9, ('138', 3): 6, ('140', 3): 6, ('46', 3): 4, ('137', 3): 4, ('15', 1): 4, ('14', 1): 4, ('163', 1): 2, ('96', 3): 1, ('78', 3): 1, ('141', 3): 1, ('136', 3): 1, ('56', 0): 1, ('57', 0): 1, ('55', 1): 1})

# %% [markdown]
# ## Comparing Images over all Flights

# %%
areas = []
aspects = []
fractions = []
for img in X: 
    h, w = img.size

    area = h * w   
    areas.append(area)
    aspect = w / h
    aspects.append(aspect)
    
    img = np.array(img) 
    mask = img > img.mean()
    animal_fraction = mask.mean()
    fractions.append(animal_fraction)

fig, ax = plt.subplots(1, 3, figsize=(12, 4))
ax[0].set_title("Aspect Ratios over all flights")
ax[0].hist(aspects, bins=50)

ax[1].hist(areas, bins=50)
ax[1].set_title("Areas over all flights")

ax[2].hist(fractions, bins=50)
ax[2].set_title("Animal fractions over all flights")
plt.show()

# %%
shapes = Counter([img.size for img in X])

for shape, count in shapes.most_common(20):
    print(shape, count)
# Out:
# (66, 94) 415
# (68, 50) 280
# (67, 94) 269
# (69, 58) 265
# (62, 70) 171
# (70, 59) 170
# (58, 51) 166
# (68, 70) 152
# (56, 50) 140
# (46, 44) 135
# (62, 62) 134
# (54, 64) 126
# (26, 24) 123
# (62, 56) 123
# (24, 20) 120
# (62, 46) 120
# (63, 68) 118
# (68, 63) 114
# (48, 42) 111
# (26, 27) 110

# %%
areas = [img.size[0]*img.size[1] for img in X]

print(np.percentile(areas, [1,5,10,25,50,75,90,95,99]))
# Out:
# [ 624. 1443. 1890. 2680. 3685. 4900. 6298. 7200. 9800.]

# %% [markdown]
# ## Investigating RGB Images

# %%
import matplotlib.pyplot as plt
import numpy as np

train = np.load("../train.npz")
X_train = train["X"]
y_train = train["y"]

val = np.load("../val.npz")
X_val = val["X"]
y_val = val["y"]

test = np.load("../test.npz")
X_test = test["X"]
y_test = test["y"]

X_train_rgb = X_train[:, :, :, 1:]
X_val_rgb = X_val[:, :, :, 1:]
X_test_rgb = X_test[:, :, :, 1:]

X_train_thermal = X_train[:, :, :, 0:1]
X_val_thermal = X_val[:, :, :, 0:1]
X_test_thermal = X_test[:, :, :, 0:1]

# %%
rgb = X_train[1,...,1:]         
thermal = X_train[1,...,0]

plt.imshow(rgb)

plt.imshow(
    thermal,
    cmap="inferno",
    alpha=0.4
)

plt.axis("off")
plt.show()

# %%
i = np.random.randint(len(X_train))

thermal = X_train[i,:,:,0]
rgb = X_train[i,:,:,1:]

fig, ax = plt.subplots(1,2, figsize=(8,4))

ax[0].imshow(thermal, cmap="gray")
ax[0].set_title(f"thermal, class {y_train[i]}")

ax[1].imshow(rgb)
ax[1].set_title(f"rgb, class {y_train[i]}")

plt.show() # this shows the problem with the rgb images -> the animals are completely hiddens

# %%
for c in np.unique(y_train):
    print(c, X_train_rgb[y_train==c].mean(), X_val_rgb[y_val==c].mean(), X_test_rgb[y_test==c].mean())
# Out:
# 0 0.4230355 0.52164626 0.38185683
# 1 0.42460495 0.37091747 0.41686347
# 2 0.47207353 0.3350285 0.40628076
# 3 0.41451883 0.40878865 0.40732086
# 4 0.36019364 0.41298887 0.46630767

# %%
for c in np.unique(y_train):
    print(c, X_train_thermal[y_train==c].mean(), X_val_thermal[y_val==c].mean(), X_test_thermal[y_test==c].mean())
# Out:
# 0 -0.17893803 -0.30599833 -0.43650728
# 1 0.072712764 -0.117623545 -0.0109132575
# 2 -0.014313351 -0.5392405 -0.42853355
# 3 -0.013887639 0.37273276 0.55102307
# 4 0.009775603 0.24444437 0.08666982

# %%
flight_train = np.array(flight_train, dtype=np.int32)
flight_val = np.array(flight_val, dtype=np.int32)
flight_test = np.array(flight_test, dtype=np.int32)

# %%
for flight in np.unique(flight_train):
    imgs = X_train_thermal[flight_train == flight]

    print(flight, imgs.mean(), imgs.std(), imgs.min(), imgs.max())
# Out:
# 0 -0.68520653 0.4892958 -1.9445431 3.16849
# 1 -0.3914021 0.8602536 -1.9445431 3.16849
# 2 -0.28398633 0.8002617 -1.9445431 3.16849
# 3 -0.020573877 0.74340606 -1.9445431 3.16849
# 17 -0.021968508 1.1662053 -1.9445431 3.16849
# 18 0.80797404 0.87870884 -1.9445431 3.16849
# 20 0.17846416 0.82594687 -1.9445431 3.0481832
# 21 0.30605078 1.0368464 -1.9445431 2.9679787
# 26 0.044653695 1.3069515 -1.9445431 3.16849
# 27 0.25928286 1.2250434 -1.9445431 3.16849
# 28 -0.2754913 0.95732576 -1.9445431 3.16849
# 29 -0.469779 1.207574 -1.9445431 3.16849
# 30 -0.5383857 1.1334378 -1.9445431 3.16849
# 31 -0.4223166 0.9600891 -1.9445431 3.16849
# 32 -0.11828466 0.8736884 -1.9445431 3.16849
# 33 -0.32171118 0.99220407 -1.9445431 3.16849
# 34 -0.42243487 1.0740615 -1.9445431 3.16849
# 35 -0.51146024 1.0682982 -1.9445431 3.16849
# 36 -0.29804307 1.0734226 -1.9445431 3.16849
# 37 -0.41026902 0.85352504 -1.9445431 3.16849
# 40 0.19497892 0.8999076 -1.9445431 3.16849
# 41 -0.41488874 0.8984222 -1.9445431 3.16849
# 42 -0.2638638 1.0509349 -1.9445431 3.16849
# 44 -0.11260973 1.2668433 -1.9445431 3.16849
# 45 0.27025092 1.1308017 -1.9445431 3.16849
# 46 0.57272893 0.9419461 -1.9445431 3.16849
# 47 0.39944434 0.9880192 -1.9445431 3.16849
# 48 0.07906375 1.0888791 -1.9445431 3.16849
# 52 0.9835439 0.9965827 -1.9445431 3.16849
# 53 0.8933939 1.0173113 -1.9445431 3.16849
# 54 0.092870526 1.1198859 -1.9445431 3.16849
# 70 0.07166518 0.8893548 -1.9445431 3.16849
# 71 -0.0010787686 0.8853623 -1.9445431 3.16849
# 72 -0.08365911 0.96086055 -1.9445431 3.16849
# 74 -0.03415716 0.87924665 -1.9445431 3.16849
# 75 -0.20037307 1.0117754 -1.9445431 3.16849
# 76 0.0003280897 0.9214912 -1.9445431 3.16849
# 77 0.031071387 1.0636966 -1.9445431 3.16849
# 78 0.02651477 0.87692004 -1.9445431 3.16849
# 79 -0.02924854 0.91124773 -1.9445431 3.16849
# 80 -0.023013754 0.98534644 -1.9445431 3.16849
# 81 0.28607053 0.961588 -1.9445431 3.16849
# 82 0.14116073 0.94666314 -1.9445431 3.16849
# 83 0.29097864 0.80852646 -1.9445431 3.16849
# 84 0.4730902 0.7855512 -1.9445431 3.16849
# 85 0.3581196 0.8480187 -1.9445431 3.16849
# 86 0.11084362 0.85917944 -1.9445431 3.16849
# 92 0.2261563 0.9686763 -1.9445431 3.16849
# 93 0.11504415 0.8853595 -1.9445431 3.16849
# 94 0.37706718 0.92313933 -1.9445431 3.16849
# 95 0.06471531 0.86684245 -1.9445431 3.16849
# 96 0.20033143 0.8872127 -1.9445431 3.16849
# 98 -0.076849245 0.72152185 -1.9445431 3.16849
# 99 0.032498106 0.81115735 -1.9445431 3.16849
# 100 0.11562979 0.77204376 -1.9445431 3.16849
# 101 0.09348091 0.92910403 -1.9445431 3.16849
# 102 -0.0053684525 0.9305903 -1.9445431 3.16849
# 103 0.2740149 0.81373674 -1.9445431 3.16849
# 104 0.24726528 0.91649526 -1.9445431 3.16849
# 105 0.32130897 1.0652986 -1.9445431 3.16849
# 106 -0.2143406 0.8638718 -1.9445431 3.16849
# 111 -0.07994904 0.5927579 -1.9445431 3.16849
# 112 -0.1623743 0.73527384 -1.9445431 3.16849
# 113 -0.23357138 0.5579625 -1.9445431 3.16849
# 114 -0.30119866 0.51468486 -1.9445431 3.0882854
# 115 -0.1411847 0.5974022 -1.9445431 3.16849
# 116 -0.33971146 0.5745508 -1.9445431 3.16849
# 117 -0.14897196 0.7140748 -1.9445431 3.16849
# 118 -0.20638597 0.70588726 -1.9445431 3.16849
# 119 0.15149625 0.6106509 -1.9445431 3.16849
# 120 0.0015716248 0.6068665 -1.9445431 3.16849
# 121 0.061816208 0.61359525 -1.9445431 3.16849
# 122 -0.11324558 0.6380099 -1.9445431 3.16849
# 123 0.014030085 0.755069 -1.9445431 3.16849
# 124 0.050938737 0.5805859 -1.9445431 3.16849
# 129 -0.018672833 0.7209384 -1.9445431 1.7649122
# 130 0.03318814 1.0612463 -1.9445431 3.16849
# 131 -0.07634122 1.0709912 -1.9445431 3.16849
# 132 -0.0758814 1.1013372 -1.9445431 3.16849
# 134 -0.41272092 0.7907473 -1.9445431 2.2461388
# 136 -0.25479484 0.8391728 -1.9445431 2.2461388
# 137 0.13113616 0.8947592 -1.9445431 2.7674677
# 138 0.31412148 1.0160459 -1.9445431 2.9278767
# 139 0.3051423 0.89216757 -1.9445431 2.8877745
# 141 0.42402825 0.93573266 -1.9445431 3.16849
# 155 0.1172435 0.69367707 -1.9445431 2.2260878
# 156 0.18279855 0.70482504 -1.9445431 2.5268545
# 179 -0.357523 0.7335682 -1.9445431 3.16849
# 180 -0.50665 0.8294001 -1.9445431 3.16849
# 181 -0.38104138 0.7010028 -1.9445431 3.16849
# 182 -0.3269487 0.7579726 -1.9445431 3.16849
# 183 -0.48423603 0.7177571 -1.9445431 3.16849
# 184 -0.38017985 0.8090038 -1.9445431 3.16849
# 185 -0.7920347 1.084916 -1.9445431 3.16849
# 186 -0.59118694 0.96312344 -1.9445431 3.16849
# 187 -0.6588516 1.0316669 -1.9445431 3.16849
# 188 0.59380686 0.7752897 -1.9445431 3.16849
# 189 0.5051818 0.97971535 -1.9445431 3.16849
# 190 0.7497268 0.9145541 -1.9445431 3.16849
# 191 0.6913556 0.75418746 -1.9445431 3.16849
# 192 0.5999548 0.8023193 -1.9445431 3.16849
# 193 0.31834897 0.8468211 -1.9445431 3.16849
# 194 0.3434041 0.8342611 -1.9445431 3.16849
# 195 0.21446651 0.8426783 -1.9445431 3.16849
# 196 0.3809673 0.86976486 -1.9445431 3.16849
# 197 0.6969221 0.74339676 -1.9445431 3.16849
# 198 0.91741633 0.96804625 -1.9445431 3.16849
# 199 0.23249845 0.940533 -1.9445431 3.16849
# 200 -0.67506474 0.616759 -1.9445431 2.80757
# 201 -0.38463345 0.9230152 -1.9445431 3.16849
# 202 -0.23850924 0.7441675 -1.9445431 3.16849
# 204 -0.36032057 0.96077514 -1.9445431 3.16849
# 205 -0.46420005 0.99811894 -1.924492 3.16849
# 206 -0.5435848 1.0817415 -1.9445431 3.16849
# 207 -0.41485596 0.72854817 -1.9445431 3.16849
# 209 -0.65013576 0.78802043 -1.9445431 3.16849
# 210 -0.40409964 0.7885243 -1.9445431 3.16849
# 211 -0.6804737 1.095502 -1.9445431 3.16849
# 212 -0.79305845 1.2182833 -1.9445431 3.16849
# 213 -0.036731873 1.2063066 -1.9445431 3.16849
# 215 -0.37379226 1.1442294 -1.9445431 3.16849
# 216 -0.5652136 1.0933062 -1.9445431 3.16849
# 224 0.21684536 0.81811255 -1.9445431 3.148439
# 225 -0.098506294 1.0864986 -1.9445431 3.16849
# 226 0.3669527 0.65114605 -1.9445431 2.26619
# 227 0.0381862 0.5156186 -1.9445431 1.8651677
# 228 0.1358829 1.0117325 -1.9445431 3.16849
# 229 -0.5578389 1.1530148 -1.9445431 3.16849
# 230 -0.26206625 1.028783 -1.9445431 3.16849
# 231 0.3440273 0.8158604 -1.9445431 3.16849
# 232 0.16170852 0.92637473 -1.9445431 3.16849
# 234 -0.017274449 0.851333 -1.9445431 3.16849
# 235 0.11707977 0.83905333 -1.9445431 3.16849
# 236 0.25294766 0.91080785 -1.9445431 3.16849
# 237 0.22504702 0.8963576 -1.9445431 3.16849
# 238 0.11281378 0.91664946 -1.9445431 3.16849
# 239 -0.002755302 0.8086429 -1.9445431 3.16849
# 240 0.12967685 0.8898612 -1.9445431 3.16849
# 241 0.026284786 0.851661 -1.9445431 3.16849
# 242 -0.23813228 0.817615 -1.9445431 3.16849
# 243 -0.17381229 0.84057844 -1.9445431 3.16849
# 244 -0.2470431 0.89197415 -1.9445431 3.16849
# 245 -0.31254575 0.895959 -1.9445431 3.16849
# 246 0.015755845 0.79728395 -1.9445431 3.0481832
# 247 -0.15546934 0.7898954 -1.9445431 2.7073145
# 248 0.34948727 1.2742416 -1.9445431 3.16849
# 249 0.14700718 1.389322 -1.9445431 3.16849
# 251 -0.29743314 1.1385678 -1.9445431 3.16849
# 256 0.03853811 0.9061968 -1.9445431 3.16849
# 294 -0.44915077 0.7781876 -1.383112 2.6672122
# 295 -0.25104362 0.7332258 -1.9445431 3.16849
# 301 -0.557411 0.54691476 -1.4633164 2.62711
# 302 -0.46484402 0.61060554 -1.9445431 3.16849
# 304 -0.6249715 0.49548703 -1.7039298 3.0882854
# 305 -0.67732614 0.49641836 -1.5435209 2.8677232
# 346 -0.49398866 0.9461036 -1.9445431 3.16849
# 347 -0.64106905 1.132612 -1.9445431 3.16849
# 348 -0.5971915 0.8704802 -1.9445431 3.16849
# 349 -0.068001255 1.1751837 -1.9445431 3.16849

# %%
for flight in np.unique(flight_val):
    imgs = X_val_thermal[flight_val == flight]

    print(flight, imgs.mean(), imgs.std(), imgs.min(), imgs.max())
# Out:
# 6 -0.06826571 0.9274386 -1.9445431 3.16849
# 10 -0.11704056 0.7819097 -1.9445431 3.16849
# 13 -0.31673503 1.0552466 -1.9445431 3.16849
# 14 -0.14724703 1.058397 -1.9445431 3.16849
# 15 0.055683795 1.1946781 -1.9445431 3.16849
# 22 -0.37542883 0.57924587 -1.9445431 3.16849
# 56 -0.23664415 0.5754866 -1.9445431 3.1283877
# 57 -0.36317268 0.70211995 -1.9445431 3.16849
# 59 -0.06017558 0.58723027 -1.9445431 0.8425612
# 64 0.049984276 0.623094 -1.9445431 1.0029701
# 66 -0.43800807 0.9164901 -1.9445431 3.16849
# 67 0.5944149 0.6324678 -0.88183427 3.16849
# 87 -0.23763886 0.44112587 -1.6838787 1.8050145
# 89 0.11676612 0.7959486 -1.9445431 2.5870078
# 142 0.34881243 0.83695257 -1.9445431 3.16849
# 143 -0.35347807 1.3397212 -1.9445431 3.16849
# 150 -0.1300006 0.6563881 -1.9445431 2.5068033
# 175 0.11186124 0.6112521 -1.9445431 2.08573
# 176 0.06806842 1.1497536 -1.9445431 3.16849
# 177 -0.41756266 1.1584207 -1.9445431 3.16849
# 178 0.032616068 1.0489798 -1.9445431 3.16849
# 221 -0.41919068 0.7055859 -1.9445431 3.16849
# 222 -0.24881683 0.7899185 -1.9445431 3.16849
# 223 -0.22239672 0.851297 -1.9445431 3.16849

# %%
for flight in np.unique(flight_test):
    imgs = X_test_thermal[flight_test == flight]

    print(flight, imgs.mean(), imgs.std(), imgs.min(), imgs.max())
# Out:
# 50 -0.4145402 0.75285673 -1.9445431 0.62199897
# 55 -0.09290065 1.0996451 -1.9445431 3.16849
# 135 -0.16768175 0.8537556 -1.9445431 3.16849
# 140 0.33494917 1.0382165 -1.9445431 3.16849
# 152 -0.062380206 0.500949 -1.9445431 3.16849
# 159 -0.036433876 1.0697068 -1.9445431 3.16849
# 160 -0.483162 0.930364 -1.9445431 3.16849
# 161 0.19558941 1.1412306 -1.9445431 3.16849
# 162 -0.35176077 1.0544974 -1.9445431 3.16849
# 163 0.1130251 1.2433699 -1.9445431 3.16849
# 250 0.14119038 1.4458362 -1.9445431 3.16849
# 252 -0.26783413 1.0805372 -1.9445431 3.16849
# 260 -0.7453107 0.9866859 -1.9445431 3.16849
# 261 -0.5449167 0.93039477 -1.9445431 3.16849
# 262 -0.00883594 1.1902505 -1.9445431 3.16849
# 263 -0.38520342 1.2536296 -1.9445431 3.16849
# 264 -0.2040053 0.993562 -1.9445431 3.16849
# 265 -1.0862297 0.93027884 -1.9445431 3.16849
# 266 -0.2551932 0.98178905 -1.924492 3.16849
# 267 1.2910595 0.37374362 0.62199897 3.16849
# 276 0.7739134 1.0786955 -1.9445431 3.16849
# 277 1.050654 0.98169553 -1.9445431 3.16849
# 278 -0.07679803 1.077049 -1.9445431 3.16849
# 279 0.7716589 0.9478694 -1.9445431 3.16849
# 280 0.76485884 0.85902053 -1.9445431 3.16849
# 281 0.0104722185 0.9360794 -1.9445431 3.16849
# 282 0.8254138 0.9549745 -1.9445431 3.16849
# 283 0.9151846 0.98747313 -1.9445431 3.16849
# 284 0.71997076 1.0884815 -1.9445431 3.16849
# 296 -0.32390532 0.70140994 -1.9445431 3.16849
# 297 -0.2973088 0.56983966 -1.9445431 3.16849
# 298 -0.25040966 0.6630959 -1.9445431 3.16849
# 299 -0.48203462 0.7492251 -1.8843898 3.16849
# 300 -0.501702 0.5584359 -1.9445431 3.16849
# 303 -0.26745665 0.46691987 -1.9445431 1.8852189
# 307 -0.4420426 0.72763455 -1.9445431 3.16849
# 308 -0.59601283 0.5205454 -1.9445431 3.16849
# 309 -0.5156705 0.66456044 -1.9445431 3.16849
# 314 -0.50594926 1.1507365 -1.9445431 3.16849
# 343 -0.34765732 0.87292 -1.9445431 3.16849
# 344 -0.87261075 0.80870605 -1.9445431 3.16849
# 345 -0.6806482 0.8722254 -1.9445431 3.16849

# %% [markdown]
# ## Masked RGB Images
#
# I also tried to mask the RGB images, meaning making everything black except for the animal figure in the corresponding thermal image.

# %%
from species_classification import mask_rgb
masked_rgbs = mask_rgb(X_val)

# %%
fig, ax = plt.subplots(1, 3, figsize=(10, 6))
ax[0].imshow(X_val[1,:,:,0], cmap='inferno')

ax[1].imshow(masked_rgbs[1, :, :, 1:], cmap='inferno')

ax[2].imshow(X_val[1,:,:,1:])
plt.show()

# %% [markdown]
# # Model Evaluations
#
# In this segment I will load all the models and run the evaluation.

# %%
from species_classification import load_model, create_binary_dataset

# %% [markdown]
# ## Models trained on Thermal Data
# I did not save every model I trained

# %% [markdown]
# ## Binary Classification
# As a further prove that classification in the 5 different species is not really successful on our dataset, I decided to transform the 5 classes into only 2 - deer or pig. In class 0 (deer) there are Roe Deer, Red Deer, and Fallow Deer, in class 1 (pig) Wild Boar and Hybrid Pig.
#
# ### Thermal Images only
# this is the model:
# ```python
# data_augmentation = tf.keras.Sequential([
#     tf.keras.layers.RandomRotation(0.1),
#     tf.keras.layers.RandomZoom(0.1)
# ])
#
# model = tf.keras.Sequential(
#     [
#         tf.keras.layers.Input(shape=input_shape),
#         data_augmentation,
#         tf.keras.layers.Conv2D(64, 3, activation="relu"),
#         BatchNormalization(),
#         tf.keras.layers.MaxPooling2D(),
#         tf.keras.layers.Conv2D(128, 3, activation="relu"),
#         BatchNormalization(),
#         tf.keras.layers.MaxPooling2D(),
#         tf.keras.layers.Conv2D(256, 3, activation="relu"),
#         BatchNormalization(),
#         tf.keras.layers.GlobalAveragePooling2D(),
#         tf.keras.layers.Dense(32, activation="relu"),
#         BatchNormalization(),
#         tf.keras.layers.Dropout(0.4),
#         tf.keras.layers.Dense(2, activation="softmax"),
#     ]
# )
#
# model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
#     loss="sparse_categorical_crossentropy",
#     metrics=["accuracy"],
# )
# ```

# %%
y_train_bin = create_binary_dataset(y_train)
y_val_bin = create_binary_dataset(y_val)
y_test_bin = create_binary_dataset(y_test)

# %%
load_model("../species_class_models/binary_thermal.keras", X_train_thermal, y_train_bin, X_val_thermal, y_val_bin, X_test_thermal, y_test_bin)
# Out:
# W0000 00:00:1781547887.394449   43864 cpu_allocator_impl.cc:82] Allocation of 2034040832 exceeds 10% of free system memory.
# 970/970 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.8096 - loss: 0.4073
# Train loss: 0.4073324501514435
# Train accuracy: 0.809614360332489
# 970/970 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step
# [[15396  1443]
#  [ 4466  9732]]
# Balanced accuracy: 0.799877364961358
#               precision    recall  f1-score   support
#
#            0      0.775     0.914     0.839     16839
#            1      0.871     0.685     0.767     14198
#
#     accuracy                          0.810     31037
#    macro avg      0.823     0.800     0.803     31037
# weighted avg      0.819     0.810     0.806     31037
#
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8519 - loss: 0.3631
# Val loss: 0.3631243109703064
# Val accuracy: 0.8518655300140381
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
# [[3963  491]
#  [ 311  649]]
# Balanced accuracy: 0.7829018391707828
#               precision    recall  f1-score   support
#
#            0      0.927     0.890     0.908      4454
#            1      0.569     0.676     0.618       960
#
#     accuracy                          0.852      5414
#    macro avg      0.748     0.783     0.763      5414
# weighted avg      0.864     0.852     0.857      5414
#
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6690 - loss: 0.7046
# Test loss: 0.7046250104904175
# Test accuracy: 0.6689714789390564
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
# [[1999  522]
#  [1010 1097]]
# Balanced accuracy: 0.6567923886435103
#               precision    recall  f1-score   support
#
#            0      0.664     0.793     0.723      2521
#            1      0.678     0.521     0.589      2107
#
#     accuracy                          0.669      4628
#    macro avg      0.671     0.657     0.656      4628
# weighted avg      0.670     0.669     0.662      4628

# %% [markdown]
# ### Thermal + RGB Images

# %%
load_model("../species_class_models/binary_classification.keras", X_train, y_train_bin, X_val, y_val_bin, X_test, y_test_bin)
# Out:
# 970/970 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - accuracy: 0.8806 - loss: 0.3079
# Train loss: 0.3078826069831848
# Train accuracy: 0.8805941343307495
# 970/970 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step
# [[15695  1144]
#  [ 2562 11636]]
# Balanced accuracy: 0.8758072618015478
#               precision    recall  f1-score   support
#
#            0      0.860     0.932     0.894     16839
#            1      0.910     0.820     0.863     14198
#
#     accuracy                          0.881     31037
#    macro avg      0.885     0.876     0.879     31037
# weighted avg      0.883     0.881     0.880     31037
#
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8731 - loss: 0.3485
# Val loss: 0.34850171208381653
# Val accuracy: 0.8731067776679993
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
# [[4010  444]
#  [ 243  717]]
# Balanced accuracy: 0.8235946621014818
#               precision    recall  f1-score   support
#
#            0      0.943     0.900     0.921      4454
#            1      0.618     0.747     0.676       960
#
#     accuracy                          0.873      5414
#    macro avg      0.780     0.824     0.799      5414
# weighted avg      0.885     0.873     0.878      5414
#
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5916 - loss: 1.3128
# Test loss: 1.3128082752227783
# Test accuracy: 0.5916162729263306
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
# [[1824  697]
#  [1193  914]]
# Balanced accuracy: 0.5786572666205676
#               precision    recall  f1-score   support
#
#            0      0.605     0.724     0.659      2521
#            1      0.567     0.434     0.492      2107
#
#     accuracy                          0.592      4628
#    macro avg      0.586     0.579     0.575      4628
# weighted avg      0.588     0.592     0.583      4628

# %% [markdown]
# ## Custom Split
# To investigate further whether the differences in the flights of the train, val, and test dataset is one of the main reasons for the poor model performance, I concatenated all datasets and customly split it with sklearn.train_test_split. With stratify I also made sure that in every dataset there is the same class distribution.
#
# Without fine-tuning the parameters of the following model, I already achieved a test accuracy of over 70%.
# ```python
# data_augmentation = tf.keras.Sequential([
#     tf.keras.layers.RandomRotation(0.1),
#     tf.keras.layers.RandomZoom(0.1),
# ])
#
# model = tf.keras.Sequential(
#     [
#         tf.keras.layers.Input(shape=input_shape),
#         data_augmentation,
#         tf.keras.layers.Conv2D(64, 3, activation="relu"),
#         BatchNormalization(),
#         tf.keras.layers.MaxPooling2D(),
#         tf.keras.layers.Conv2D(128, 3, activation="relu"),
#         BatchNormalization(),
#         tf.keras.layers.MaxPooling2D(),
#         tf.keras.layers.Conv2D(256, 3, activation="relu"),
#         BatchNormalization(),
#         tf.keras.layers.GlobalAveragePooling2D(),
#         tf.keras.layers.Dense(32, activation="relu"),  #256
#         BatchNormalization(),
#         tf.keras.layers.Dropout(0.4),
#         tf.keras.layers.Dense(num_classes, activation="softmax"),
#     ]
# )
#
# model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
#     loss="sparse_categorical_crossentropy",
#     metrics=["accuracy"],
# )
# ```

# %%
load_model("../species_class_models/custom_split.keras", X_train_thermal, y_train, X_val_thermal, y_val, X_test_thermal, y_test)
